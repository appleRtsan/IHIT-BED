# %%
import pandas as pd
import matplotlib.pyplot as plt
from pytorch_tabnet.tab_model import TabNetClassifier
from sklearn.metrics import roc_auc_score

# %%
loaded_clf = TabNetClassifier()
loaded_clf.load_model("BC classifier/model.zip")
# Out:
# C:\Users\User\AppData\Roaming\Python\Python310\site-packages\pytorch_tabnet\abstract_model.py:75: UserWarning: Device used : cpu
#   warnings.warn(f"Device used : {self.device}")

# %%
# feature indexing for BC classifier
fi = []
with open ("BC classifier/feature indexing.txt",'r') as f:
    
    while True:
        s = f.readline().strip('\n')
        if not s:
            break
        # print(s)
        fi.append(str(s))
        
fi
# Out:
# ['WBC24',
#  'WBC25',
#  'WBC26',
#  'WBC27',
#  'WBC28',
#  'WBC29',
#  'WBC30',
#  'WBC128',
#  'WBC129',
#  'WBC130',
#  'WBC131',
#  'WBC132',
#  'WBC133',
#  'WBC134',
#  'WBC135',
#  'WBC136',
#  'WBC137',
#  'WBC138',
#  'WBC139',
#  'WBC127',
#  'WBC23',
#  'WBC126',
#  'WBC31',
#  'WBC125',
#  'WBC140',
#  'WBC124',
#  'WBC141',
#  'WBC123',
#  'WBC142',
#  'WBC22',
#  'WBC32',
#  'WBC122',
#  'WBC121',
#  'WBC143',
#  'WBC120',
#  'WBC21',
#  'WBC33',
#  'WBC119',
#  'WBC144',
#  'WBC118',
#  'WBC34',
#  'WBC145',
#  'WBC20',
#  'WBC117',
#  'WBC146',
#  'WBC35',
#  'WBC116',
#  'WBC147',
#  'WBC19',
#  'WBC148',
#  'WBC115',
#  'WBC36',
#  'WBC114',
#  'WBC149',
#  'WBC37',
#  'WBC18',
#  'WBC150',
#  'WBC113',
#  'WBC151',
#  'WBC38',
#  'WBC112',
#  'WBC152',
#  'WBC17',
#  'WBC39',
#  'WBC153',
#  'WBC111',
#  'WBC154',
#  'WBC110',
#  'WBC40',
#  'WBC155',
#  'WBC16',
#  'WBC109',
#  'WBC156',
#  'WBC41',
#  'WBC108',
#  'WBC157',
#  'WBC107',
#  'WBC158',
#  'WBC42',
#  'Plt27',
#  'Plt28',
#  'WBC15',
#  'WBC106',
#  'WBC159',
#  'Plt26',
#  'WBC105',
#  'WBC160',
#  'Plt29',
#  'Plt25',
#  'WBC43',
#  'WBC104',
#  'WBC161',
#  'WBC4',
#  'WBC1',
#  'WBC3',
#  'WBC2',
#  'WBC103',
#  'Plt24',
#  'WBC162',
#  'Plt30',
#  'WBC256',
#  'WBC5',
#  'WBC102',
#  'WBC254',
#  'WBC255',
#  'WBC163',
#  'WBC250',
#  'WBC44',
#  'WBC14',
#  'WBC249',
#  'WBC101',
#  'WBC253',
#  'WBC251',
#  'WBC246',
#  'WBC164',
#  'WBC245',
#  'WBC252',
#  'WBC248',
#  'WBC100',
#  'Plt23',
#  'WBC244',
#  'WBC247',
#  'WBC165',
#  'WBC242',
#  'WBC99',
#  'Plt31',
#  'WBC243',
#  'WBC166',
#  'WBC241',
#  'WBC6',
#  'WBC45',
#  'WBC98',
#  'WBC240',
#  'WBC167',
#  'WBC238',
#  'WBC168',
#  'WBC239',
#  'Plt22',
#  'WBC237',
#  'WBC97',
#  'WBC169',
#  'WBC235',
#  'WBC236',
#  'Plt32',
#  'WBC170',
#  'WBC96',
#  'WBC171',
#  'WBC234',
#  'WBC233',
#  'WBC232',
#  'WBC172',
#  'WBC13',
#  'WBC46',
#  'WBC231',
#  'WBC95',
#  'WBC173',
#  'Plt21',
#  'WBC230',
#  'WBC174',
#  'WBC175',
#  'WBC229',
#  'WBC94',
#  'WBC176',
#  'WBC228',
#  'WBC177',
#  'WBC178',
#  'WBC93',
#  'WBC227',
#  'WBC226',
#  'Plt33',
#  'WBC7',
#  'WBC225',
#  'WBC179',
#  'WBC47',
#  'WBC180',
#  'WBC181',
#  'WBC224',
#  'Plt20',
#  'WBC92',
#  'WBC223',
#  'WBC182',
#  'WBC221',
#  'WBC183',
#  'WBC222',
#  'WBC185',
#  'WBC184',
#  'WBC220',
#  'WBC186',
#  'WBC91',
#  'WBC219',
#  'WBC217',
#  'WBC187',
#  'WBC218',
#  'WBC216',
#  'WBC188',
#  'WBC189',
#  'WBC190',
#  'WBC191',
#  'WBC215',
#  'WBC212',
#  'WBC192',
#  'WBC193',
#  'WBC209',
#  'WBC210',
#  'WBC214',
#  'WBC194',
#  'WBC211',
#  'WBC213',
#  'WBC90',
#  'WBC208',
#  'WBC195',
#  'Plt34',
#  'WBC48',
#  'WBC206',
#  'WBC207',
#  'WBC199',
#  'WBC205',
#  'WBC197',
#  'WBC196',
#  'WBC198',
#  'WBC200',
#  'WBC201',
#  'WBC204',
#  'WBC203',
#  'Plt19',
#  'WBC202',
#  'WBC89',
#  'WBC12',
#  'WBC88',
#  'WBC87',
#  'WBC49',
#  'Plt35',
#  'WBC86',
#  'Plt18',
#  'WBC85',
#  'WBC84',
#  'WBC8',
#  'WBC50',
#  'WBC83',
#  'Plt36',
#  'Plt6',
#  'WBC82',
#  'Plt17',
#  'Plt7',
#  'WBC81',
#  'WBC51',
#  'WBC80',
#  'Plt8',
#  'Plt66',
#  'Plt68',
#  'Plt69',
#  'Plt37',
#  'WBC79',
#  'Plt67',
#  'Plt65',
#  'Plt70',
#  'Plt64',
#  'Plt71',
#  'WBC78',
#  'Plt75',
#  'Plt72',
#  'Plt73',
#  'Plt16',
#  'WBC52',
#  'WBC11',
#  'Plt63',
#  'Plt74',
#  'Plt76',
#  'WBC77',
#  'Plt77',
#  'Plt62',
#  'Plt78',
#  'Plt9',
#  'Plt79',
#  'Plt61',
#  'WBC76',
#  'Plt60',
#  'Plt38',
#  'Plt80',
#  'WBC75',
#  'WBC53',
#  'Plt81',
#  'Plt59',
#  'Plt58',
#  'Plt82',
#  'WBC74',
#  'Plt83',
#  'WBC73',
#  'Plt15',
#  'Plt57',
#  'Plt84',
#  'Plt56',
#  'Plt10',
#  'WBC72',
#  'Plt39',
#  'Plt85',
#  'WBC54',
#  'Plt86',
#  'Plt55',
#  'Plt87',
#  'WBC71',
#  'Plt54',
#  'Plt88',
#  'Plt89',
#  'Plt90',
#  'Plt53',
#  'WBC70',
#  'WBC9',
#  'Plt52',
#  'WBC55',
#  'WBC69',
#  'Plt40',
#  'Plt51',
#  'Plt14',
#  'Plt50',
#  'WBC68',
#  'Plt49',
#  'WBC56',
#  'WBC67',
#  'Plt11',
#  'Plt48',
#  'Plt41',
#  'WBC66',
#  'Plt47',
#  'WBC57',
#  'WBC65',
#  'WBC10',
#  'Plt42',
#  'Plt46',
#  'Plt13',
#  'WBC58',
#  'WBC64',
#  'WBC63',
#  'WBC59',
#  'Plt45',
#  'Plt43',
#  'Plt12',
#  'WBC62',
#  'WBC60',
#  'Plt44']

# %%
df_test = pd.read_excel('example cohort.xlsx') # second independent testing cohort


for i in range(len(df_test)):
    if df_test.loc[i,'CRP'] > 10.0 :
        df_test.loc[i,'CRP_class'] = 1
    else:
        df_test.loc[i,'CRP_class'] = 0
        
X_test = df_test[fi].values
y_test = df_test['Blood Culture'].values

# %%
preds = loaded_clf.predict(X_test)

print(roc_auc_score(df_test['Blood Culture'].values, preds))
# Out:
# 0.8513513513513513

# %%
loaded_clf_CRP = TabNetClassifier()
loaded_clf_CRP.load_model("CRP classifier/model.zip")
CRP_features = [ col for col in df_test.columns if col not in ["CRP_class"]+["CRP"]+['Barcode']+['Blood Culture']+['preds']+['preds_CRP']]
X_test = df_test[CRP_features].values
y_test = df_test['CRP_class'].values
# Out:
# C:\Users\User\AppData\Roaming\Python\Python310\site-packages\pytorch_tabnet\abstract_model.py:75: UserWarning: Device used : cpu
#   warnings.warn(f"Device used : {self.device}")

# %%
preds_CRP = loaded_clf_CRP.predict_proba(X_test)[:,-1]

print(roc_auc_score(df_test['CRP_class'].values, preds_CRP))
# Out:
# 0.8004535147392291
